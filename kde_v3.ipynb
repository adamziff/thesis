# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.9/site-packages (2.21.0)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.12)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (4.3.4)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: deprecated>=1.2.3 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (1.2.13)
# Requirement already satisfied: packaging>=20.4 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.12.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install urllib3 --upgrade 
# %pip install requests --upgrade 
# %pip install spotipy --upgrade
# Out:
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.9/site-packages (1.26.12)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.9/site-packages (2.21.0)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (4.3.4)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.12)
# Requirement already satisfied: deprecated>=1.2.3 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (1.2.13)
# Requirement already satisfied: packaging>=20.4 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (21.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.12.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# setup
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
import numpy as np
import timeit
import pandas as pd
from operator import itemgetter
import time
import datetime as dt
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.spatial.distance as dist

os.environ['SPOTIPY_CLIENT_ID'] = '3191e7e8b04e46c1af64f49bcdd020be'
os.environ['SPOTIPY_CLIENT_SECRET'] = '88dc925eff0d4006bb6d0b9b2401ac59'

auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# Toxic, Promiscuous, Sk8er Boi, Run It!, Your Love Is My Drug
user_0 = ['6I9VzXrHxO9rA9A5euc8Ak', '2gam98EZKrF9XuOkU13ApN', '4omisSlTk6Dsq2iQD7MA07', '7xYnUQigPoIDAMPVK79NEq', '3uoQULcUWfnt6nc6J7Vgai']

# This Hell
user_1 = ['7aHmvUghK3XCEqNRbUeAn4']

# Down (Jay Sean), INDUSTRY BABY
user_2 = ['7LP4Es66zdY7CyjepqmvAg', '27NovPIUIRrOZoCHxABJwK']

# Pepas, Me Porto Bonito, Tití Me Preguntó
user_3 = ['5fwSHlTEWpluwOM0Sxnh5k', '6Sq7ltF9Qa7SNFBsV5Cogx', '1IHWl5LamUGEuP4ozKQSXZ']

# All Night Longer, Mr. Brightside, No Hands, HUMBLE
user_4 = ['1vNn7rVQT6UtEW1NGH53fT', '003vvx7Niy0yvhvHt4a68B', '03tqyYWC9Um2ZqU0ZN849H', '7KXjTSCq5nL1LoYtL7XAwS']

# S&M, Get Into It (Yuh), Only Girl In The World, Gimme Gimme Gimme, Don't Start Now
user_5 = ['7ySUcLPVX7KudhnmNcgY2D', '4V5siYO9zHpLX5qf2F0qBV', '1VDXQhu7YGdbM6UeEIfsaX', '7lkeI7MsLOZ5gyh9ejaf3W', '6WrI0LAC5M1Rw2MnX2ZvEg']

# In The Party (Flo Milli), Tap In (Saweetie), Woman (Doja Cat), Only, Hot Girl (Megan Thee Stallion)
user_6 = ['52BJrldggFQyTiW8XrILhO', '4Hpib09wXgD84w4uwTPnYD', '6Uj1ctrBOjOas8xZXGqKk4', '4MRT0dDbhqFKl67WzhUbSw', '2Xc9MR2NMc5IKPFKaEjt1k']

# Love Story, You Belong With Me, Starships, Super Bass, Since U Been Gone
user_7 = ['3CeCwYWvdfXbZLXFhBrbnf', '1qrpoAMXodY6895hGKoUpA', '1oHNvJVbFkexQc0BpQp7Y4', '3hlksXnvbKogFdPbpO9vel', '3xrn9i8zhNZsTtcoWgQEAd']

# A Milli, 6 Foot 7 Foot, Money In The Grave, Jimmy Cooks
user_8 = ['6ScJMrlpiLfZUGtWp4QIVt', '5Qy6a5KzM4XlRxsNcGYhgH', '5ry2OE6R2zPQFDO85XkgRb', '3F5CgOj3wFlRv51JsHbxhe']

# BREAK MY SOUL, PURE/HONEY, ALIEN SUPERSTAR
user_9 = ['5pyoxDZ1PX0KxBxiRVxA4U', '4DByEumlGTZKSzuVEZ35eo', '1Hohk6AufHZOrrhMXZppax']

# The Baddest, Let's Get Weird, Astro Funk, Griztronics II, Tie Dye Sky
user_10 = ['2xOrdBxmf58MfWbe3JXxlM', '0NQVIXbk5AIHzNrBdlcTP9', '7wRzUAw0Npu4CalkDIFHJE', '2il9NDpW87Hk2L9AjeDf8r', '2YZSTgWXEyDPUeKop4eiWo']

# Mozart
user_11 = ['429GaRIWKJ3EU1GAQPbLcr']

users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11]

# %%
def print_tracks(uris):
    #recurse through all uris
    if len(uris) > 50:
        num_sets = int(len(uris)/50)
        for i in range(num_sets):
            print_tracks(uris[50*i:50*(i+1)])
        if len(uris)%50 != 0:
            print_tracks(uris[50*num_sets:])
        return

    # collect chosen tracks
    chosen_tracks = sp.tracks(uris)
    chosen_tracks_dict = pd.DataFrame(chosen_tracks['tracks'])
    chosen_tracks_names = chosen_tracks_dict['name']
    chosen_artists_dict = chosen_tracks_dict['artists']
    chosen_artists = []
    for song in chosen_artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        chosen_artists.append(a)

    # print chosen tracks
    for i in range(len(chosen_tracks_names)):
        chosen_artists_string = ''
        for j in range(len(chosen_artists[i])):
            # print(artist)
            chosen_artists_string += chosen_artists[i][j]
            if j < len(chosen_artists[i])-1:
                chosen_artists_string += ', '
        print(chosen_tracks_names[i] + ' by ' + chosen_artists_string)
    
    # print(pd.DataFrame(np.array([np.array(chosen_tracks_names), chosen_artists]).T))

# %%
def print_recs(uris, limit):
    # collect chosen tracks
    chosen_tracks = sp.tracks(uris)
    chosen_tracks_dict = pd.DataFrame(chosen_tracks['tracks'])
    chosen_tracks_names = chosen_tracks_dict['name']
    chosen_artists_dict = chosen_tracks_dict['artists']
    chosen_artists = []
    for song in chosen_artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        chosen_artists.append(a)

    # print chosen tracks
    print('Chosen Tracks:')
    for i in range(len(chosen_tracks_names)):
        chosen_artists_string = ''
        for j in range(len(chosen_artists[i])):
            # print(artist)
            chosen_artists_string += chosen_artists[i][j]
            if j < len(chosen_artists[i])-1:
                chosen_artists_string += ', '
        print(chosen_tracks_names[i] + ' by ' + chosen_artists_string)
    
    # print(pd.DataFrame(np.array([np.array(chosen_tracks_names), chosen_artists]).T))

    print()

    # collect recommendations
    recs = pd.DataFrame(sp.recommendations(seed_tracks=uris, limit=limit)['tracks'])
    track_names = recs['name']
    rec_artists_dict = recs['artists']
    rec_artists = []
    for song in rec_artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        rec_artists.append(a)


    print('Recommended Tracks:')
    # print recommendations
    for i in range(limit):
        rec_artists_string = ''
        for j in range(len(rec_artists[i])):
            # print(artist)
            rec_artists_string += rec_artists[i][j]
            if j < len(rec_artists[i])-1:
                rec_artists_string += ', '
        print(track_names[i] + ' by ' + rec_artists_string)

    # print(pd.DataFrame(np.array([np.array(track_names), artists]).T))

# %%
# Scale features to range of [-1,1]
def scale_features(features):
    scaler = StandardScaler()
    scaler.fit(features)
    scaled_features = pd.DataFrame(scaler.transform(features))
    return scaled_features, scaler

# %%
NUM_RECOMMENDATIONS = 100
def get_recommendations(uris):
    recommendations_uris = pd.DataFrame(sp.recommendations(seed_tracks=uris, limit=NUM_RECOMMENDATIONS)['tracks'])['uri']
    return sp.audio_features(recommendations_uris)

# %%
MS_IN_DAY = 86400
# get artist, artist genres, popularity, date
def get_track_values(uris):
    # return values are messed up - gotta pass through the return values!!
    extra_uris = []
    if len(uris) > 50:
        extra_uris = uris[50:]
        uris = uris[:50]

    # collect chosen tracks
    tracks = sp.tracks(uris)
    tracks_dict = pd.DataFrame(tracks['tracks'])

    popularity = list(tracks_dict['popularity'])

    artists_dict = tracks_dict['artists']
    artists = []
    for song in artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        artists.append(a)

    # get genres
    # flatten artists list, make sure len < 50, get genres - prob separate method

    albums_dict = pd.DataFrame(tracks_dict['album'].to_list())
    unconverted_dates = albums_dict['release_date']
    dates = []
    # datetime conversion
    for date in unconverted_dates:
        while len(date) < 10:
            date += '-01'
        ms_date = dt.datetime.timestamp(dt.datetime.strptime(date,"%Y-%m-%d"))
        dates.append(ms_date / MS_IN_DAY)
    
    track_values = [artists, popularity, dates]
    
    if len(extra_uris) > 0:
        recur_values = get_track_values(extra_uris)
        for i in range(len(track_values)):
            track_values[i].extend(recur_values[i])
    return track_values

# %%
CHOSEN_FEATURES_WEIGHT = 100
# function to get audio features, gkde, and scaler from a set of 1-5 URIs
def get_values(uris, print_songs = False):
    assert(len(uris) <= 5)

    # Get audio features for user's chosen tracks from Spotify API
    chosen_features = sp.audio_features(uris)
    
    if print_songs:
        print('Chosen Tracks:')
        print_tracks(uris)
        print()

    # Get audio features for user's recommended tracks from Spotify API
    recommendations_features = get_recommendations(uris)
    if print_songs:
        print('Recommended Tracks: ')
        print_tracks(pd.DataFrame(recommendations_features)['uri'])
        print()
    
    # Create unweighted list of all features
    unweighted_features = pd.DataFrame(chosen_features + recommendations_features)
    unweighted_features = unweighted_features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)

    # Create weighted list of all features favoring chosen features
    weighted_features = pd.DataFrame(chosen_features * CHOSEN_FEATURES_WEIGHT + recommendations_features)
    weighted_features = weighted_features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)

    recommendations_uris = pd.DataFrame(recommendations_features)['uri']

    return unweighted_features, weighted_features, recommendations_uris
    # return unweighted_features, unweighted_scaler, weighted_features, weighted_scaler, recommendations_uris

# %%
# function to get audio features, gkde, and scaler from a set of 1-5 URIs
def get_values_without_recs(uris):
    assert(len(uris) <= 5)

    # Get audio features for user's chosen tracks from Spotify API
    chosen_features = sp.audio_features(uris)
    
    # Create unweighted list of all features
    unweighted_features = pd.DataFrame(chosen_features)
    unweighted_features = unweighted_features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)
    # Scale features to have mean 0 and var 1
    unweighted_features, unweighted_scaler = scale_features(unweighted_features)

    return unweighted_features, unweighted_scaler

# %%
ARTIST_PENALTY = 0.05
def evaluate_gkde(uri, gkde, scaler, eval_artists):
    # get audio features
    # print('len(uris)', len(uri))
    features = pd.DataFrame(sp.audio_features(uri))
    features = features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)
    artists, popularity, dates = get_track_values([uri])
    features['popularity'] = popularity
    features['date'] = dates
    artists = artists[0]
    
    penalty = 1
    artist_included = any(a in eval_artists for a in artists)
    if not artist_included:
        penalty -= ARTIST_PENALTY
    else:
        print('Not Penalized')

    # scale using given gkde's parameters
    mean, var = scaler.mean_, scaler.var_
    # print('features type ', type(features))
    # print(features)
    features = (features - mean) / np.sqrt(var)

    # print('pre eval')
    # print(gkde.evaluate(features))
    # print('post eval')

    # evaluate similarity
    return gkde.evaluate(features) * penalty

# %%
def evaluate_cos(uri, user_features, scaler, eval_artists):
    # get audio features
    features = pd.DataFrame(sp.audio_features(uri))
    features = features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)
    artists, popularity, dates = get_track_values([uri])
    features['popularity'] = popularity
    features['date'] = dates
    artists = artists[0]

    penalty = 1
    artist_included = any(a in eval_artists for a in artists)
    if not artist_included:
        penalty += ARTIST_PENALTY #has to change if metric values low/high values
    else:
        print('Not Penalized')

    distances = np.array([])
    for i in range(len(user_features)):
        distances = np.append(distances, dist.cosine(features, user_features.iloc[[i]]))
    
    return np.mean(distances) * penalty

# %%
# NOTES

# try euclidean distance instead of cosine distance, just try diff metrics (l2, standard, etc)
# also try computing similarity with respect to the chosen songs w/o recommendations
# test the metric between two songs i think should be similar and two songs i think should be different

# hyperparameter penalty metric for genre and artist
# if artist doesn't match, penalize score by hyperparameter
# do an analysis using only the artist and genre to see how effective these are as a metric

# TODO:

# implement genre hyperparameter penalty

# compare similarity with and without including recommendations
# compare similarity between songs I think should be similar vs different
# look at feature values for songs that I think are similar vs different
# test different hyperparameter values

# %%
def get_features(uris):
    n = len(uris)
    uf, wf, rec_uris = get_values(uris)
    vals = get_track_values(uris + list(rec_uris))
    # print(vals)
    artists = vals[0]
    popularity = vals[1]
    dates = vals[2]
    # rec_uris_list = rec_uris_list.append(rec_uris)

    # add to uf
    uf['popularity'] = popularity
    uf['date'] = dates

    # add to wf in a weighted way
    wf['popularity'] = (popularity[:n] * CHOSEN_FEATURES_WEIGHT) + popularity[n:]
    wf['date'] = (dates[:n] * CHOSEN_FEATURES_WEIGHT) + dates[n:]
    return uf, wf, rec_uris, artists

# %%
# Griztronics
test_uri = '6OTClxme7EYRZGO6An3SMc'

# Sk8er Boi
# test_uri = '4omisSlTk6Dsq2iQD7MA07'

all_unweighted_features = pd.DataFrame()
all_weighted_features = pd.DataFrame()

rec_uris_list = []
artists_list = []

for i in range(len(users)):
    uf, wf, rec_uris, artists = get_features(users[i])

    all_unweighted_features = pd.concat([all_unweighted_features, uf])
    all_weighted_features = pd.concat([all_weighted_features, wf])
    rec_uris_list.append(rec_uris)
    artists_list.append(artists)

# get scalers - can make this more efficient by just getting the mean and var
_, unweighted_scaler = scale_features(all_unweighted_features)
_, weighted_scaler = scale_features(all_weighted_features)
u_mean, u_var = unweighted_scaler.mean_, unweighted_scaler.var_
w_mean, w_var = weighted_scaler.mean_, weighted_scaler.var_

# print(np.shape(artists_list))

u_start_index = 0
w_start_index = 0
for i in range(len(users)):
    # get user's features
    u_end_index = u_start_index + NUM_RECOMMENDATIONS + len(users[i])
    w_end_index = w_start_index + NUM_RECOMMENDATIONS + (len(users[i] * CHOSEN_FEATURES_WEIGHT))

    uf = all_unweighted_features.iloc[u_start_index:u_end_index]
    # print(np.shape(artists_list[u_start_index:u_end_index]))
    user_artists = [a for song in artists_list[i] for a in song]
    u_start_index = u_end_index

    wf = all_weighted_features.iloc[w_start_index:w_end_index]
    w_start_index = w_end_index

    # scale features
    uf = (uf - u_mean) / np.sqrt(u_var)
    wf = (wf - w_mean) / np.sqrt(w_var)

    # calculate gkdes
    u_gkde = stats.gaussian_kde(uf.T)
    w_gkde = stats.gaussian_kde(wf.T)

    print_tracks(users[i])
    print('User ' + str(i) + ' GKDE Unweighted Utility: ', evaluate_gkde(test_uri, u_gkde, unweighted_scaler, user_artists))
    print('User ' + str(i) + ' GKDE Weighted Utility: ', evaluate_gkde(test_uri, w_gkde, weighted_scaler, user_artists))
    print('User ' + str(i) + ' Cosine Unweighted Utility: ', evaluate_cos(test_uri, uf, unweighted_scaler, user_artists))
    print('User ' + str(i) + ' Cosine Weighted Utility: ', evaluate_cos(test_uri, wf, weighted_scaler, user_artists))
    print()
# Out:
# Toxic by Britney Spears
# Promiscuous by Nelly Furtado, Timbaland
# Sk8er Boi by Avril Lavigne
# Run It! (feat. Juelz Santana) by Chris Brown, Juelz Santana
# Your Love Is My Drug by Kesha
# User 0 GKDE Unweighted Utility:  [6.16990699e-11]
# User 0 GKDE Weighted Utility:  [4.99683272e-46]
# User 0 Cosine Unweighted Utility:  1.3317156268714965
# User 0 Cosine Weighted Utility:  1.4604480482773143
#
# This Hell by Rina Sawayama
# User 1 GKDE Unweighted Utility:  [1.42496515e-17]
# User 1 GKDE Weighted Utility:  [1.77830181e-28]
# User 1 Cosine Unweighted Utility:  0.7197402550428922
# User 1 Cosine Weighted Utility:  0.5703962778607041
#
# Down by Jay Sean, Lil Wayne
# INDUSTRY BABY (feat. Jack Harlow) by Lil Nas X, Jack Harlow
# User 2 GKDE Unweighted Utility:  [1.02935244e-07]
# User 2 GKDE Weighted Utility:  [1.8857664e-15]
# User 2 Cosine Unweighted Utility:  0.9862684092238435
# User 2 Cosine Weighted Utility:  0.9803811258537389
#
# Pepas by Farruko
# Me Porto Bonito by Bad Bunny, Chencho Corleone
# Tití Me Preguntó by Bad Bunny
# User 3 GKDE Unweighted Utility:  [1.10554507e-10]
# User 3 GKDE Weighted Utility:  [1.59709668e-11]
# User 3 Cosine Unweighted Utility:  0.8271919787682157
# User 3 Cosine Weighted Utility:  0.6839502671920784
#
# All Night Longer by Sammy Adams
# Mr. Brightside by The Killers
# No Hands (feat. Roscoe Dash & Wale) by Waka Flocka Flame, Roscoe Dash, Wale
# HUMBLE. by Kendrick Lamar
# User 4 GKDE Unweighted Utility:  [3.05301055e-07]
# User 4 GKDE Weighted Utility:  [1.23233792e-16]
# User 4 Cosine Unweighted Utility:  1.2072404534502488
# User 4 Cosine Weighted Utility:  1.2803565258409244
#
# S&M by Rihanna
# Get Into It (Yuh) by Doja Cat
# Only Girl (In The World) by Rihanna
# Gimme! Gimme! Gimme! (A Man After Midnight) - From 'Mamma Mia!' Original Motion Picture Soundtrack by Amanda Seyfried, Ashley Lilley, Rachel McDowall
# Don't Start Now by Dua Lipa
# User 5 GKDE Unweighted Utility:  [1.50571926e-12]
# User 5 GKDE Weighted Utility:  [1.38616033e-35]
# User 5 Cosine Unweighted Utility:  1.0543527802229389
# User 5 Cosine Weighted Utility:  1.1329866737410565
#
# In The Party by Flo Milli
# Tap In by Saweetie
# Woman by Doja Cat
# Only by Nicki Minaj, Drake, Lil Wayne, Chris Brown
# Hot Girl by Megan Thee Stallion
# User 6 GKDE Unweighted Utility:  [5.97223087e-07]
# User 6 GKDE Weighted Utility:  [8.64446045e-30]
# User 6 Cosine Unweighted Utility:  0.8820558009065808
# User 6 Cosine Weighted Utility:  0.8273035167794602
#
# Love Story (Taylor’s Version) by Taylor Swift
# You Belong With Me (Taylor’s Version) by Taylor Swift
# Starships by Nicki Minaj
# Super Bass by Nicki Minaj
# Since U Been Gone by Kelly Clarkson
# User 7 GKDE Unweighted Utility:  [4.73258123e-09]
# User 7 GKDE Weighted Utility:  [1.16349474e-30]
# User 7 Cosine Unweighted Utility:  1.1476778798067515
# User 7 Cosine Weighted Utility:  1.1310550983386067
#
# A Milli by Lil Wayne
# 6 Foot 7 Foot by Lil Wayne, Cory Gunz
# Money In The Grave (Drake ft. Rick Ross) by Drake, Rick Ross
# Jimmy Cooks (feat. 21 Savage) by Drake, 21 Savage
# User 8 GKDE Unweighted Utility:  [6.11967532e-18]
# User 8 GKDE Weighted Utility:  [1.03169944e-63]
# User 8 Cosine Unweighted Utility:  0.9584478179663373
# User 8 Cosine Weighted Utility:  1.027236774299434
#
# BREAK MY SOUL by Beyoncé
# PURE/HONEY by Beyoncé
# ALIEN SUPERSTAR by Beyoncé
# User 9 GKDE Unweighted Utility:  [1.09297093e-08]
# User 9 GKDE Weighted Utility:  [1.63421977e-22]
# User 9 Cosine Unweighted Utility:  0.7971711674497783
# User 9 Cosine Weighted Utility:  0.5947463993610635
#
# The Baddest by GRiZ
# Let's Get Weird by GRiZ
# Astro Funk by GRiZ
# Griztronics II (Another Level) by GRiZ, Subtronics
# Tie-Dye Sky by GRiZ
# Not Penalized
# User 10 GKDE Unweighted Utility:  [1.08825932e-06]
# Not Penalized
# User 10 GKDE Weighted Utility:  [1.01433653e-12]
# Not Penalized
# User 10 Cosine Unweighted Utility:  0.8451113733458456
# Not Penalized
# User 10 Cosine Weighted Utility:  0.7498594584163242
#
# Piano Concerto No. 21 in C Major, K. 467: II. Andante by Wolfgang Amadeus Mozart, London Mozart Players, Howard Shelley
# User 11 GKDE Unweighted Utility:  [9.84935341e-245]
# User 11 GKDE Weighted Utility:  [0.]
# User 11 Cosine Unweighted Utility:  1.2802615786057805
# User 11 Cosine Weighted Utility:  1.2936529255757716

# %%
# notes from prof li
# make a diagram of data flow for utility function process

# notes for raja:

# sp.recommendations is nondeterministic, gives different recomendations each time even with same seed

# %%
a = [[1,2], [3,4,5]]
b = [n for l in a for n in l]
print(b)
# Out:
# [1, 2, 3, 4, 5]
