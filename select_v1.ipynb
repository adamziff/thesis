# %%
pip install spotipy

# %%
pip install pandas

# %%
# %pip install urllib3 --upgrade 
# %pip install requests --upgrade 
# %pip install spotipy --upgrade

# %%
# setup
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
import numpy as np
import timeit
import pandas as pd
from operator import itemgetter
import time
import datetime as dt
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.spatial.distance as dist
import random

os.environ['SPOTIPY_CLIENT_ID'] = '3191e7e8b04e46c1af64f49bcdd020be'
os.environ['SPOTIPY_CLIENT_SECRET'] = '88dc925eff0d4006bb6d0b9b2401ac59'

auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# Toxic, Promiscuous, Sk8er Boi, Run It!, Your Love Is My Drug
user_0 = ['6I9VzXrHxO9rA9A5euc8Ak', '2gam98EZKrF9XuOkU13ApN', '4omisSlTk6Dsq2iQD7MA07', '7xYnUQigPoIDAMPVK79NEq', '3uoQULcUWfnt6nc6J7Vgai']

# This Hell
user_1 = ['7aHmvUghK3XCEqNRbUeAn4']

# Down (Jay Sean), INDUSTRY BABY
user_2 = ['7LP4Es66zdY7CyjepqmvAg', '27NovPIUIRrOZoCHxABJwK']

# Pepas, Me Porto Bonito, Tití Me Preguntó
user_3 = ['5fwSHlTEWpluwOM0Sxnh5k', '6Sq7ltF9Qa7SNFBsV5Cogx', '1IHWl5LamUGEuP4ozKQSXZ']

# All Night Longer, Mr. Brightside, No Hands, HUMBLE
user_4 = ['1vNn7rVQT6UtEW1NGH53fT', '003vvx7Niy0yvhvHt4a68B', '03tqyYWC9Um2ZqU0ZN849H', '7KXjTSCq5nL1LoYtL7XAwS']

# S&M, Get Into It (Yuh), Only Girl In The World, Gimme Gimme Gimme, Don't Start Now
user_5 = ['7ySUcLPVX7KudhnmNcgY2D', '4V5siYO9zHpLX5qf2F0qBV', '1VDXQhu7YGdbM6UeEIfsaX', '7lkeI7MsLOZ5gyh9ejaf3W', '6WrI0LAC5M1Rw2MnX2ZvEg']

# In The Party (Flo Milli), Tap In (Saweetie), Woman (Doja Cat), Only, Hot Girl (Megan Thee Stallion)
user_6 = ['52BJrldggFQyTiW8XrILhO', '4Hpib09wXgD84w4uwTPnYD', '6Uj1ctrBOjOas8xZXGqKk4', '4MRT0dDbhqFKl67WzhUbSw', '2Xc9MR2NMc5IKPFKaEjt1k']

# Love Story, You Belong With Me, Starships, Super Bass, Since U Been Gone
user_7 = ['3CeCwYWvdfXbZLXFhBrbnf', '1qrpoAMXodY6895hGKoUpA', '1oHNvJVbFkexQc0BpQp7Y4', '3hlksXnvbKogFdPbpO9vel', '3xrn9i8zhNZsTtcoWgQEAd']

# A Milli, 6 Foot 7 Foot, Money In The Grave, Jimmy Cooks
user_8 = ['6ScJMrlpiLfZUGtWp4QIVt', '5Qy6a5KzM4XlRxsNcGYhgH', '5ry2OE6R2zPQFDO85XkgRb', '3F5CgOj3wFlRv51JsHbxhe']

# BREAK MY SOUL, PURE/HONEY, ALIEN SUPERSTAR
user_9 = ['5pyoxDZ1PX0KxBxiRVxA4U', '4DByEumlGTZKSzuVEZ35eo', '1Hohk6AufHZOrrhMXZppax']

# The Baddest, Let's Get Weird, Astro Funk, Griztronics II, Tie Dye Sky
user_10 = ['2xOrdBxmf58MfWbe3JXxlM', '0NQVIXbk5AIHzNrBdlcTP9', '7wRzUAw0Npu4CalkDIFHJE', '2il9NDpW87Hk2L9AjeDf8r', '2YZSTgWXEyDPUeKop4eiWo']

# Mozart
user_11 = ['429GaRIWKJ3EU1GAQPbLcr']

# Can't Hold Us, Feel This Moment, Give Me Everything
user_12 = ['3bidbhpOYeV4knp8AIu8Xn', '0Hf4aIJpsN4Os2f0y0VqWl', '4QNpBfC0zvjKqPJcyqBy9W']

# Timber, Last Friday Night
user_13 = ['3cHyrEgdyYRjgJKSOiOtcS', '3avYqdwHKEq8beXbeWCKqJ']

# DJ Got Us Fallin In Love, Down Jay Sean, I Love It, Timber
user_14 = ['28AUzRo0nQLESL55WDV0um', '7LP4Es66zdY7CyjepqmvAg', '6HZ9VeI5IRFCNQLXhpF4bq', '3cHyrEgdyYRjgJKSOiOtcS']

users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11, user_12, user_13, user_14]

# %%
def print_tracks(uris):
    #recurse through all uris
    if len(uris) > 50:
        num_sets = int(len(uris)/50)
        for i in range(num_sets):
            print_tracks(uris[50*i:50*(i+1)])
        if len(uris)%50 != 0:
            print_tracks(uris[50*num_sets:])
        return

    # collect chosen tracks
    chosen_tracks = sp.tracks(uris)
    chosen_tracks_dict = pd.DataFrame(chosen_tracks['tracks'])
    chosen_tracks_names = chosen_tracks_dict['name']
    chosen_artists_dict = chosen_tracks_dict['artists']
    chosen_artists = []
    for song in chosen_artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        chosen_artists.append(a)

    # print chosen tracks
    for i in range(len(chosen_tracks_names)):
        chosen_artists_string = ''
        for j in range(len(chosen_artists[i])):
            # print(artist)
            chosen_artists_string += chosen_artists[i][j]
            if j < len(chosen_artists[i])-1:
                chosen_artists_string += ', '
        print(chosen_tracks_names[i] + ' by ' + chosen_artists_string)

# %%
# Scale features to range of [-1,1]
def scale_features(features):
    scaler = StandardScaler()
    scaler.fit(features)
    scaled_features = pd.DataFrame(scaler.transform(features))
    return scaled_features, scaler

# %%
NUM_RECOMMENDATIONS = 100
def get_recommendations(uris):
    recommendations_uris = pd.DataFrame(sp.recommendations(seed_tracks=uris, limit=NUM_RECOMMENDATIONS)['tracks'])['uri']
    return sp.audio_features(recommendations_uris)

# %%
MS_IN_DAY = 86400
# get artist, artist genres, popularity, date
def get_track_values(uris):
    # return values are messed up - gotta pass through the return values!!
    extra_uris = []
    if len(uris) > 50:
        extra_uris = uris[50:]
        uris = uris[:50]

    # collect chosen tracks
    tracks = sp.tracks(uris)
    tracks_dict = pd.DataFrame(tracks['tracks'])

    popularity = list(tracks_dict['popularity'])
    names = list(tracks_dict['name'])

    artists_dict = tracks_dict['artists']
    artists = []
    for song in artists_dict:
        a = []
        for artist in song:
            a.append(artist['name'])
        artists.append(a)

    # get genres
    # flatten artists list, make sure len < 50, get genres - prob separate method

    albums_dict = pd.DataFrame(tracks_dict['album'].to_list())
    unconverted_dates = albums_dict['release_date']
    dates = []
    # datetime conversion
    for date in unconverted_dates:
        while len(date) < 10:
            date += '-01'
        ms_date = dt.datetime.timestamp(dt.datetime.strptime(date,"%Y-%m-%d"))
        dates.append(ms_date / MS_IN_DAY)
    
    track_values = [artists, popularity, dates, names]
    
    if len(extra_uris) > 0:
        recur_values = get_track_values(extra_uris)
        for i in range(len(track_values)):
            track_values[i].extend(recur_values[i])
    return track_values

# %%
CHOSEN_FEATURES_WEIGHT = 100
# function to get audio features, gkde, and scaler from a set of 1-5 URIs
def get_values(uris, print_songs = False):
    assert(len(uris) <= 5)

    # Get audio features for user's chosen tracks from Spotify API
    chosen_features = sp.audio_features(uris)
    
    if print_songs:
        print('Chosen Tracks:')
        print_tracks(uris)
        print()

    # Get audio features for user's recommended tracks from Spotify API
    recommendations_features = get_recommendations(uris)
    if print_songs:
        print('Recommended Tracks: ')
        print_tracks(pd.DataFrame(recommendations_features)['uri'])
        print()
    
    # Create unweighted list of all features
    unweighted_features = pd.DataFrame(chosen_features + recommendations_features)
    unweighted_features = unweighted_features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)

    # Create weighted list of all features favoring chosen features
    weighted_features = pd.DataFrame(chosen_features * CHOSEN_FEATURES_WEIGHT + recommendations_features)
    weighted_features = weighted_features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)

    recommendations_uris = pd.DataFrame(recommendations_features)['uri']

    return unweighted_features, weighted_features, recommendations_uris
    # return unweighted_features, unweighted_scaler, weighted_features, weighted_scaler, recommendations_uris

# %%
ARTIST_PENALTY = 0.05
# evaluate using cosine distance
def evaluate(uri, user_avg, eval_artists, scale_mean, scale_var):
    # get audio features
    features = pd.DataFrame(sp.audio_features(uri))
    features = features.drop(['key', 'loudness', 'mode', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)
    artists, popularity, dates, _ = get_track_values([uri])
    features['popularity'] = popularity
    features['date'] = dates
    artists = artists[0]

    # scale the features array
    features = (features - scale_mean) / np.sqrt(scale_var)

    penalty = 1
    artist_included = any(a in eval_artists for a in artists)
    if not artist_included:
        penalty += ARTIST_PENALTY
        # print('Penalized')
    
    return dist.cosine(features, user_avg) * ARTIST_PENALTY

# %%
def get_features(uris):
    n = len(uris)
    uf, wf, rec_uris = get_values(uris)
    artists, popularity, dates, names = get_track_values(uris + list(rec_uris))
    # rec_uris_list = rec_uris_list.append(rec_uris)

    # add to uf
    uf['popularity'] = popularity
    uf['date'] = dates

    # add to wf in a weighted way
    wf['popularity'] = (popularity[:n] * CHOSEN_FEATURES_WEIGHT) + popularity[n:]
    wf['date'] = (dates[:n] * CHOSEN_FEATURES_WEIGHT) + dates[n:]
    return uf, wf, rec_uris, artists, names

# %%
# set up utility function for each user
# take the average over all user's features then calculate distance to that
# get all features, scale, take average
def get_utilfuncs_and_allsongs(users_uris):
    all_unweighted_features = pd.DataFrame()
    all_weighted_features = pd.DataFrame()

    n = len(users_uris)

    all_uris_list = []
    artists_list = []
    names_list = []

    for i in range(n):
        uf, wf, rec_uris, artists, names = get_features(users[i])

        all_unweighted_features = pd.concat([all_unweighted_features, uf])
        all_weighted_features = pd.concat([all_weighted_features, wf])
        all_uris_list.extend(users[i])
        all_uris_list.extend(rec_uris)
        artists_list.append(artists)
        names_list.append(names[:len(users_uris[i])])

    # get scalers - can make this more efficient by just scaling everything in the scale_features function
    all_unweighted_features, _ = scale_features(all_unweighted_features) 
    # _, weighted_scaler = scale_features(all_weighted_features) # unweighted or weighted?
    # u_mean, u_var = unweighted_scaler.mean_, unweighted_scaler.var_

    u_start_index = 0
    w_start_index = 0

    u_user_avgs = []
    w_user_avgs = []

    for i in range(n):
        # get user's features
        u_end_index = u_start_index + NUM_RECOMMENDATIONS + len(users_uris[i])
        w_end_index = w_start_index + NUM_RECOMMENDATIONS + (len(users_uris[i] * CHOSEN_FEATURES_WEIGHT))

        uf = all_unweighted_features.iloc[u_start_index:u_end_index]
        wf = all_weighted_features.iloc[w_start_index:w_end_index]

        # scale features
        # uf = (uf - u_mean) / np.sqrt(u_var)
        # wf = (wf - u_mean) / np.sqrt(u_var)
        
        u_start_index = u_end_index
        w_start_index = w_end_index

        # take the average of uf and wf, add to array of average vectors
        u_user_avgs.append(np.mean(uf, axis=0))
        w_user_avgs.append(np.mean(wf, axis=0))

    # all_unweighted_features['uri'] = all_uris_list
    
    return u_user_avgs, w_user_avgs, all_unweighted_features, np.array(all_uris_list)

# %%
# when i call the evaluate function, send it the average instead of the whole array of features

# %% [markdown]
# tryna sort the set of songs based on utility functions
# so we already have the set of songs because we already have all_unweighted_features
# so we need to sort that list of features while maintaining original indices or maintaining sort of all_uris_list

# %%
def calculate_distances(avgs, songs):
    # print(avgs)
    # print(songs)
    dists = []
    min_dist_indices = []
    for i in range(len(avgs)):
        user_dist = 0
        min_dist_indices.append(0)
        min_dist = 1000000 # pick a high value to start
        # print('min dist for user ', i)
        for j, song in songs.iterrows():
            # print(avgs[i])
            # print(song)
            d = dist.cosine(avgs[i], song)
            # print('dist =', d)
            user_dist += d
            if d < min_dist:
                min_dist = d
                min_dist_indices[i] = j
                # print('j =', j)
        dists.append(user_dist)
    return dists, min_dist_indices

# %%
# needs to adjust dynamically to length
NUM_SONGS_TO_SELECT = 30

# %%
# SORT! random, unweighted
# currently using unweighted, consider changing to weighted
def select_songs_random_unweighted(users_uris):
    u_user_avgs, w_user_avgs, all_features, all_uris_list = get_utilfuncs_and_allsongs(users_uris)
    n = len(all_features)
    # needs to adjust dynamically to length
    # NUM_SONGS_TO_SELECT = 10

    # start with random set of songs - selected array is indices of selected songs
    selected_ind = random.sample(range(n), NUM_SONGS_TO_SELECT)

    # loop until done
    done = False
    t = 0

    while not done:
        # calculate sum of user utilities for every song in the set
        current_selected_f = all_features.iloc[selected_ind]
        current_dists = calculate_distances(u_user_avgs, current_selected_f)
        current_maximin = max(current_dists)
        
        # print('t =', t)
        print('current max dist user:', np.argmax(current_dists))
        # print(current_dists)

        # pick new song
        new_selected = random.randrange(0,n)
        while new_selected in selected_ind:
            new_selected = random.randrange(0,n)

        # pick removed song (by choosing an index of selected_ind)
        removed_selected = random.randrange(0, NUM_SONGS_TO_SELECT)

        # update new selected indices
        new_selected_ind = selected_ind.copy()
        new_selected_ind[removed_selected] = new_selected

        # recalculate sum of user utilities
        new_selected_f = all_features.iloc[new_selected_ind]
        new_dists = calculate_distances(u_user_avgs, new_selected_f)
        new_maximin = max(new_dists)
        print('new max dist user:', np.argmax(new_dists))
        # print(new_dists)

        # determine whether to edit selected_ind list
        if new_maximin < current_maximin:
            print('edited')
            # print(selected_ind)
            selected_ind[removed_selected] = new_selected
            # print(selected_ind)
        elif random.random() < (1.0/(t+2)): # CHANGE this to use a sigmoid function
            print('randomly edited')
            selected_ind[removed_selected] = new_selected

        # check if done
        if t > 1000:
            done = True
        t += 1
        print()

    return all_uris_list[selected_ind]

# %%
uris = select_songs_random_unweighted(users)
print_tracks(uris)

# %%
# sigmoid function with beta parameter weighting
# it might be descending too quickly
def sigmoid(x, beta):
    # s = 1 / (1 + np.exp(-x))
    # print(x*beta)
    x = max(x*beta, -709)
    s = 1 / (1 + np.exp(-x))
    # print(s)
    return s

# %%
# SORT! sigmoid
# currently using unweighted, consider changing to weighted
def select_songs_sigmoid(users_uris):
    u_user_avgs, w_user_avgs, all_features, all_uris_list = get_utilfuncs_and_allsongs(users_uris)
    n = len(all_features)
    # needs to adjust dynamically to length
    # NUM_SONGS_TO_SELECT = 10

    # start with random set of songs - selected array is indices of selected songs
    selected_ind = random.sample(range(n), NUM_SONGS_TO_SELECT)

    # loop until done
    done = False
    t = 0

    while not done:
        # calculate sum of user utilities for every song in the set
        current_selected_f = all_features.iloc[selected_ind]
        current_dists = calculate_distances(u_user_avgs, current_selected_f)
        current_maximin = max(current_dists)
        
        print('t =', t)
        print('current max dist user:', np.argmax(current_dists))
        # print(current_dists)

        # pick new song
        new_selected = random.randrange(0,n)
        while new_selected in selected_ind:
            new_selected = random.randrange(0,n)

        # pick removed song (by choosing an index of selected_ind)
        removed_selected = random.randrange(0, NUM_SONGS_TO_SELECT)

        # update new selected indices
        new_selected_ind = selected_ind.copy()
        new_selected_ind[removed_selected] = new_selected

        # recalculate sum of user utilities
        new_selected_f = all_features.iloc[new_selected_ind]
        new_dists = calculate_distances(u_user_avgs, new_selected_f)
        new_maximin = max(new_dists)
        print('new max dist user:', np.argmax(new_dists))
        # print(new_dists)

        # determine whether to edit selected_ind list
        if new_maximin < current_maximin:
            print('edited')
            # print(selected_ind)
            selected_ind[removed_selected] = new_selected
            # print(selected_ind)
        elif random.random() < sigmoid(current_maximin-new_maximin, t):
            print('randomly edited')
            selected_ind[removed_selected] = new_selected

        # check if done
        if t > 1000:
            done = True
        t += 1
        print()

    return all_uris_list[selected_ind]

# %%
# users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11]
# exclude mozart
users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10]

# %%
uris = select_songs_sigmoid(users)
print_tracks(uris)

# %%
# SORT! choose add
# currently using unweighted, consider changing to weighted
def select_songs_choose_add(users_uris):
    u_user_avgs, w_user_avgs, all_features, all_uris_list = get_utilfuncs_and_allsongs(users_uris)
    n = len(all_features)
    # needs to adjust dynamically to length
    # NUM_SONGS_TO_SELECT = 10

    # start with random set of songs - selected array is indices of selected songs
    selected_ind = random.sample(range(n), NUM_SONGS_TO_SELECT)

    # loop until done
    done = False
    t = 0
    selected_changed = True

    while not done:
        # calculate sum of user utilities for every song in the set
        if selected_changed:
            current_selected_f = all_features.iloc[selected_ind]
            current_dists, min_dist_indices = calculate_distances(u_user_avgs, current_selected_f)
            current_maximin = max(current_dists)
            selected_changed = False
        
        print('t =', t)
        print('current max dist user:', np.argmax(current_dists))
        # print(current_dists)

        # pick new song - pick the worst off user's favorite song, random if already in set
        new_selected = min_dist_indices[np.argmax(current_dists)]
        while new_selected in selected_ind:
            new_selected = random.randrange(0,n)

        # pick removed song (by choosing an index of selected_ind) FIGURE THIS OUT NEXT
        removed_selected = random.randrange(0, NUM_SONGS_TO_SELECT)

        # update new selected indices
        new_selected_ind = selected_ind.copy()
        new_selected_ind[removed_selected] = new_selected

        # recalculate sum of user utilities
        new_selected_f = all_features.iloc[new_selected_ind]
        new_dists, _ = calculate_distances(u_user_avgs, new_selected_f)
        new_maximin = max(new_dists)
        print('new max dist user:', np.argmax(new_dists))
        # print(new_dists)

        # determine whether to edit selected_ind list
        if new_maximin < current_maximin:
            print('edited')
            # print(selected_ind)
            selected_ind[removed_selected] = new_selected
            # print(selected_ind)
            selected_changed = True
        elif random.random() < sigmoid(current_maximin-new_maximin, t):
            print('randomly edited')
            selected_ind[removed_selected] = new_selected
            selected_changed = True

        # check if done
        if t > 1000:
            done = True
        t += 1
        print()

    return all_uris_list[selected_ind]

# %%
uris = select_songs_choose_add(users)
print_tracks(uris)

# %%
# SORT! weighted toggle
# currently using unweighted, consider changing to weighted
def select_songs_weighted_toggle(users_uris, weighted=True):
    u_user_avgs, w_user_avgs, all_features, all_uris_list = get_utilfuncs_and_allsongs(users_uris)
    if weighted:
        avgs = w_user_avgs
    else:
        avgs = u_user_avgs
    n = len(all_features)
    # needs to adjust dynamically to length
    # NUM_SONGS_TO_SELECT = 10

    # start with random set of songs - selected array is indices of selected songs
    selected_ind = random.sample(range(n), NUM_SONGS_TO_SELECT)

    # loop until done
    done = False
    t = 0
    selected_changed = True
    best_track_worst_user_failed = False

    while not done:
        # calculate sum of user utilities for every song in the set
        if selected_changed:
            current_selected_f = all_features.iloc[selected_ind]
            current_dists, min_dist_indices = calculate_distances(avgs, current_selected_f) # THIS IS WRONG, NEEDS TO BE ALL UNSELECTED TRACKS (but that's inefficient so figure out a better way)
            current_maximin = max(current_dists)
            selected_changed = False
        
        print('t =', t)
        print('current max dist user:', np.argmax(current_dists))
        # print('current dists:')
        # print(current_dists)
        print('min dist indices:')
        print(min_dist_indices)

        # pick new song
        # pick the worst off user's favorite song, random if already in set
        best_worst = min_dist_indices[np.argmax(current_dists)]
        print('selected ind:')
        # print(best_worst)
        print(selected_ind)
        if not best_track_worst_user_failed and best_worst not in selected_ind:
            print('best worst')
            new_selected = best_worst
        else:
            new_selected = random.randrange(0,n)
            while new_selected in selected_ind:
                new_selected = random.randrange(0,n)
            print('random')

        # loop through all selected songs, try removing all until one improves the set
        for i in range(NUM_SONGS_TO_SELECT):
            removed_selected = i

            # update new selected indices
            new_selected_ind = selected_ind.copy()
            new_selected_ind[removed_selected] = new_selected

            # recalculate sum of user utilities
            new_selected_f = all_features.iloc[new_selected_ind]
            new_dists, _ = calculate_distances(avgs, new_selected_f)
            new_maximin = max(new_dists)
            # print(new_dists)

            # determine whether to edit selected_ind list
            if new_maximin < current_maximin:
                print('edited')
                # print(selected_ind)
                selected_ind[removed_selected] = new_selected
                # print(selected_ind)
                selected_changed = True
                best_track_worst_user_failed = False
                print('new max dist user:', np.argmax(new_dists))
                break
            elif random.random() < sigmoid(current_maximin-new_maximin, t):
                print('randomly edited')
                selected_ind[removed_selected] = new_selected
                selected_changed = True
                best_track_worst_user_failed = False
                print('new max dist user:', np.argmax(new_dists))
                break
            best_track_worst_user_failed = True

        # check if done
        if t > 1000:
            done = True
        t += 1
        print()

    return all_uris_list[selected_ind]

# %%
# users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11]

# %%
uris = select_songs_weighted_toggle(users, weighted=False)
print_tracks(uris)

# %% [markdown]
# there's a possibility that the best song for the worst user doesn't improve the maximin, no matter what song you remove
#
# loop through all songs, try removing them in order and check maximin
#
# if you get to the end, pick a random add song and loop through all songs to remove

# %% [markdown]
# Observations:
# - one user can totally derail the algorithm, it only changes according to the most distant user and if one user suggests some wildly different music the algorithm will very rarely change
# - algorithm can go in cycles where it tries to fix one user for a bit, then it adds enough songs where that user's distance goes down, then it tries to fix the next lowest user
# - at 10 songs, it kinda seems like it's just giving every user one song to latch on to
# - feature idea: keep these songs, regenerate the rest

# %%
# exclude mozart
users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10]
NUM_SONGS_TO_SELECT = 30
uris = select_songs_weighted_toggle(users, weighted=True)
print_tracks(uris)
# Out:
# t = 0
# current max dist user: 4
# current dists:
# [26.90018306131461, 26.894937647361694, 26.895495354243426, 26.896613827979813, 26.90115356708473, 26.897976212278575, 26.897968412902063, 26.899310291798017, 26.898482871626946, 26.896239785994762, 26.89576850040128]
# min dist indices:
# [793, 793, 793, 793, 793, 793, 793, 793, 793, 793, 793]
# best worst and selected ind:
# 793
# [942, 797, 737, 882, 478, 855, 1040, 81, 66, 804, 615, 793, 987, 274, 188, 289, 1064, 508, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 4
#
# t = 1
# current max dist user: 4
# current dists:
# [26.302136113957555, 26.29510073335951, 26.295905586379217, 26.296989835927356, 26.3031609146115, 26.298987695491327, 26.29903041628827, 26.30067073174986, 26.29958090340996, 26.296665215784717, 26.29646317830123]
# min dist indices:
# [793, 793, 793, 793, 793, 793, 793, 793, 793, 793, 793]
# best worst and selected ind:
# 793
# [942, 768, 737, 882, 478, 855, 1040, 81, 66, 804, 615, 793, 987, 274, 188, 289, 1064, 508, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# randomly edited
# new max dist user: 4
#
# t = 2
# current max dist user: 4
# current dists:
# [26.95261185168124, 26.94571585568599, 26.94661075731059, 26.946809216703336, 26.953072667815437, 26.94912417133834, 26.949354078271373, 26.95057839422813, 26.949567209581204, 26.946860965771325, 26.947620549061305]
# min dist indices:
# [793, 793, 793, 793, 793, 793, 793, 793, 793, 793, 793]
# best worst and selected ind:
# 793
# [942, 418, 737, 882, 478, 855, 1040, 81, 66, 804, 615, 793, 987, 274, 188, 289, 1064, 508, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 4
#
# t = 3
# current max dist user: 4
# current dists:
# [26.397583416544087, 26.390436165705673, 26.391251138686204, 26.39229514652981, 26.398603346811083, 26.394347356902035, 26.394435510481014, 26.39605353268785, 26.39495898742933, 26.391995109032973, 26.391878874255177]
# min dist indices:
# [793, 793, 793, 793, 793, 793, 793, 793, 793, 793, 793]
# best worst and selected ind:
# 793
# [942, 179, 737, 882, 478, 855, 1040, 81, 66, 804, 615, 793, 987, 274, 188, 289, 1064, 508, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# randomly edited
# new max dist user: 4
#
# t = 4
# current max dist user: 4
# current dists:
# [26.427840776326605, 26.422457267836457, 26.423106484632317, 26.42364856068196, 26.4284567089332, 26.425294146544932, 26.425407986965265, 26.426518858978362, 26.42571409797977, 26.423524766182428, 26.423699729025266]
# min dist indices:
# [793, 793, 793, 793, 793, 793, 793, 793, 793, 793, 793]
# best worst and selected ind:
# 793
#

# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 192, 121, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 1011, 436, 1082, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 0
#
# t = 80
# current max dist user: 0
# current dists:
# [21.64755618093296, 21.640631403172193, 21.641657361282313, 21.640856364743538, 21.64733786178991, 21.643582505113592, 21.643999433245604, 21.64479915776191, 21.643851005444063, 21.641347181347466, 21.643201397826502]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 151, 121, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 1011, 436, 1082, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 4
#
# t = 81
# current max dist user: 4
# current dists:
# [21.641785699057436, 21.634877511850952, 21.635870838298523, 21.63543960567592, 21.641790746756534, 21.638010508086232, 21.638326959178123, 21.639295451373222, 21.6383166545925, 21.635761850200296, 21.63717240211311]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 151, 1012, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 1011, 436, 1082, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 0
#
# t = 82
# current max dist user: 0
# current dists:
# [21.613615784138503, 21.607954045415557, 21.608883684209193, 21.607538467676488, 21.612983161030844, 21.610048869259707, 21.610504856886454, 21.610877893668842, 21.610142526384653, 21.608231630400976, 21.610497783566274]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 151, 1012, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 1011, 436, 761, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 0
#
# t = 83
# current max dist user: 0
# current dists:
# [21.591710199186092, 21.585274251117173, 21.586391911210647, 21.584333664907767, 21.59065797033954, 21.587407568067242, 21.588039374362555, 21.588235929401158, 21.587430429483582, 21.585350990286777, 21.58851644288108]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 151, 1012, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 1011, 436, 542, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
# edited
# new max dist user: 0
#
# t = 84
# current max dist user: 0
# current dists:
# [21.533408596670032, 21.52591713707435, 21.527166876927826, 21.525183274959677, 21.532450840009165, 21.52859278584434, 21.52924087005591, 21.529650337105316, 21.52868619081809, 21.526190429005574, 21.529415364183883]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# [153, 699, 151, 1012, 377, 735, 1040, 625, 652, 804, 615, 793, 987, 274, 188, 131, 436, 542, 749, 30, 389, 239, 988, 736, 398, 723, 864, 139, 447, 345]
# random
#
# t = 85
# current max dist user: 0
# current dists:
# [21.533408596670032, 21.52591713707435, 21.527166876927826, 21.525183274959677, 21.532450840009165, 21.52859278584434, 21.52924087005591, 21.529650337105316, 21.52868619081809, 21.526190429005574, 21.529415364183883]
# min dist indices:
# [153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153]
# best worst and selected ind:
# 153
# ...
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 943, 139, 701, 345]
# random
#
# t = 574
# current max dist user: 10
# current dists:
# [18.401650689449987, 18.400614158110283, 18.40149154236168, 18.395615455409853, 18.3979409782282, 18.39837807036875, 18.39965960919959, 18.397230050793027, 18.397518200741825, 18.398191630477964, 18.404810254744536]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 943, 139, 701, 345]
# random
#
# t = 575
# current max dist user: 10
# current dists:
# [18.401650689449987, 18.400614158110283, 18.40149154236168, 18.395615455409853, 18.3979409782282, 18.39837807036875, 18.39965960919959, 18.397230050793027, 18.397518200741825, 18.398191630477964, 18.404810254744536]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 943, 139, 701, 345]
# random
#
# t = 576
# current max dist user: 10
# current dists:
# [18.401650689449987, 18.400614158110283, 18.40149154236168, 18.395615455409853, 18.3979409782282, 18.39837807036875, 18.39965960919959, 18.397230050793027, 18.397518200741825, 18.398191630477964, 18.404810254744536]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 943, 139, 701, 345]
# random
# edited
# new max dist user: 10
#
# t = 577
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 578
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 579
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 580
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 581
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 582
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 583
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 584
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 585
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
#
# t = 586
# current max dist user: 10
# current dists:
# [18.387182493068575, 18.389315469517225, 18.389592185839646, 18.3850181857542, 18.384164515179354, 18.386141003910772, 18.387066305602715, 18.38466439061041, 18.385332322020975, 18.386974397125226, 18.391764674005163]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 701, 345]
# random
# edited
# new max dist user: 10
#
# t = 587
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 588
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 589
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 590
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 591
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 592
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 593
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
#
# t = 594
# current max dist user: 10
# current dists:
# [18.332862098936392, 18.33487036953625, 18.335163006722322, 18.330649075224837, 18.329869903853776, 18.33179017951803, 18.33268171430637, 18.330340945443666, 18.330972710645742, 18.332574974339384, 18.337294858384535]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 345]
# random
# edited
# new max dist user: 10
#
# t = 595
# current max dist user: 10
# current dists:
# [18.279555022840526, 18.280947971160096, 18.28131605032163, 18.276983799512767, 18.276678018574195, 18.27826417150372, 18.279107531254855, 18.276962374204693, 18.277482517567158, 18.278835929221643, 18.283406599221433]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 369]
# random
#
# t = 596
# current max dist user: 10
# current dists:
# [18.279555022840526, 18.280947971160096, 18.28131605032163, 18.276983799512767, 18.276678018574195, 18.27826417150372, 18.279107531254855, 18.276962374204693, 18.277482517567158, 18.278835929221643, 18.283406599221433]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 378, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 369]
# random
# edited
# new max dist user: 10
#
# t = 597
# current max dist user: 10
# current dists:
# [18.256545906504886, 18.2591288808525, 18.259298095732444, 18.25527367046227, 18.253804849282016, 18.256015055839086, 18.25673859175944, 18.25454594658602, 18.255208568505633, 18.256967473718746, 18.261035089721172]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 279, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 369]
# random
#
# t = 598
# current max dist user: 10
# current dists:
# [18.256545906504886, 18.2591288808525, 18.259298095732444, 18.25527367046227, 18.253804849282016, 18.256015055839086, 18.25673859175944, 18.25454594658602, 18.255208568505633, 18.256967473718746, 18.261035089721172]
# min dist indices:
# [331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331]
# best worst and selected ind:
# 331
# [331, 153, 279, 1015, 297, 966, 111, 936, 1026, 970, 957, 793, 162, 598, 928, 302, 401, 123, 749, 990, 389, 994, 988, 252, 398, 255, 611, 139, 910, 369]
# random
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/f1/06_sb4pj60b3_t6f1ptwvv840000gn/T/ipykernel_56159/975546787.py in <module>
#       2 users = [user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10]
#       3 NUM_SONGS_TO_SELECT = 30
# ----> 4 uris = select_songs_weighted_toggle(users, weighted=True)
#       5 print_tracks(uris)
#
# /var/folders/f1/06_sb4pj60b3_t6f1ptwvv840000gn/T/ipykernel_56159/286977311.py in select_songs_weighted_toggle(users_uris, weighted)
#      60             # recalculate sum of user utilities
#      61             new_selected_f = all_features.iloc[new_selected_ind]
# ---> 62             new_dists, _ = calculate_distances(avgs, new_selected_f)
#      63             new_maximin = max(new_dists)
#      64             # print(new_dists)
#
# /var/folders/f1/06_sb4pj60b3_t6f1ptwvv840000gn/T/ipykernel_56159/1503300003.py in calculate_distances(avgs, songs)
#      12             # print(avgs[i])
#      13             # print(song)
# ---> 14             d = dist.cosine(avgs[i], song)
#      15             # print('dist =', d)
#      16             user_dist += d
#
# /opt/anaconda3/lib/python3.9/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     745     #   or 'reflective correlation'
#     746     # clamp the result to 0-2
# --> 747     return max(0, min(correlation(u, v, w=w, centered=False), 2.0))
#     748
#     749
#
# /opt/anaconda3/lib/python3.9/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     696     uv = np.average(u * v, weights=w)
#     697     uu = np.average(np.square(u), weights=w)
# --> 698     vv = np.average(np.square(v), weights=w)
#     699     dist = 1.0 - uv / np.sqrt(uu * vv)
#     700     # Return absolute value to avoid small negative value due to rounding
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/overrides.py in average(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned, keepdims)
#     516
#     517     if weights is None:
# --> 518         avg = a.mean(axis, **keepdims_kw)
#     519         scl = avg.dtype.type(a.size/avg.size)
#     520     else:
#
# KeyboardInterrupt:

# %%
users = [user_0, user_7, user_12, user_13, user_14]
NUM_SONGS_TO_SELECT = 30
uris = select_songs_weighted_toggle(users, weighted=True)
print_tracks(uris)

# %%
# next - try weighted - WHY EDITED SO MUCH? IS THIS GOOD?
# try weighting popularity more heavily
# figure out energy

# %% [markdown]
# i have successfully built a different version of Spotify Blends
#
# how do i turn this into a DJ bot
# - map to energy curve
# - group songs by genre- do "a house set" then "a reggaeton set" then "a dubstep set"
# - could even use clustering to do the above
#
# let's test running it with a more narrow selection of users that just want bar mitzvah pop hits
#
# at some point i just run up against the limitations of spotify's data that just isn't that good
#
# mess around with weighted vs non-weighted
#
# look at avgs to see how average distances vary based on number of songs, songs in set

# %% [markdown]
# ok one problem- i need to find each user's best song out of the entire set of songs, not the songs that have already been added
#
# alternatively, i save each user's worst song out of the already selected songs and try to remove that (and go random if it doesn't work)
#
# also try messing with the parameters (NUM_RECOMMENDATIONS etc)
